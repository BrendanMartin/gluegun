# %% [markdown]
# ## TODO
# - Resize frames before saving to Google Cloud Storage

# %%
import os, sys
from PIL import Image
from hurry.filesize import size

# %%
direct = r"C:\Users\Brendan\Projects\Misc\objdetect\extractor\submissions\agg8n5\frames"
frame = '00.jpg'
path = os.path.join(direct, frame)


image = Image.open(path)

print(size(os.path.getsize(path)))
image.size
# Out:
# 81K
# (608, 1080)

# %%
new_frame = '00_opt.jpg'
new_path = os.path.join(direct, new_frame)

# %%
def scale(image):
    w, h = image.size
    w, h = int(w * .5), int(h * .5)   # scale down 50%
    return image.resize((w, h))

thumb_size = (300, 300)
image2 = image.copy()
image2.thumbnail(thumb_size)
image2.save(new_path, optimize=True, quality=80)

print(size(os.path.getsize(new_path)))

new_image = Image.open(new_path)
# Out:
# 6K

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))

ax1.imshow(image)
ax2.imshow(new_image)

# %%
# Out:
# 304.0
